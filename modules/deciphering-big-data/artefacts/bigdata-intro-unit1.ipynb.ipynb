# %%
## Artefact 1 – Big Data Overview in Swiss Cities  
This notebook explores a small dataset simulating population size, data centre presence, and average internet speeds in Swiss cities.  |

# %%
import pandas as pd

data = {
    "City": ["Zurich", "Bern", "Basel", "Geneva", "Lugano"],
    "Population_M": [0.43, 0.13, 0.18, 0.20, 0.06],
    "DataCenter": [True, True, False, True, False],
    "Avg_Internet_Speed_Mbps": [240, 220, 200, 250, 210]
}

df = pd.DataFrame(data)
display(df)

summary = df.describe(include='all')
display(summary)
# Out:
#      City  Population_M  DataCenter  Avg_Internet_Speed_Mbps
# 0  Zurich          0.43        True                      240
# 1    Bern          0.13        True                      220
# 2   Basel          0.18       False                      200
# 3  Geneva          0.20        True                      250
# 4  Lugano          0.06       False                      210
#           City  Population_M DataCenter  Avg_Internet_Speed_Mbps
# count        5      5.000000          5                 5.000000
# unique       5           NaN          2                      NaN
# top     Zurich           NaN       True                      NaN
# freq         1           NaN          3                      NaN
# mean       NaN      0.200000        NaN               224.000000
# std        NaN      0.139463        NaN                20.736441
# min        NaN      0.060000        NaN               200.000000
# 25%        NaN      0.130000        NaN               210.000000
# ...

# %%
import sys
# !{sys.executable} -m pip install matplotlib pandas
# Out:
# ...
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ---------------------------------------- 8.3/8.3 MB 46.4 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 58.8 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/7.1 MB ? eta -:--:--
#    ---------------------------------------- 7.1/7.1 MB 62.8 MB/s  0:00:00
# ...
#
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----------- ---------------------------- 2/7 [kiwisolver]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
# ...

# %%
df.plot(x="City", y="Avg_Internet_Speed_Mbps", kind="bar", title="Average Internet Speed by City", legend=False)
# Out:
# <Axes: title={'center': 'Average Internet Speed by City'}, xlabel='City'>
